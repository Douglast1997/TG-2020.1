# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %run UtilsLightGBMFingerPrinting.ipynb

# %%
# carrega tabela de erbs (não usada no treino, talvez dê algum insight)
erbs = pd.read_csv('databases/Bts.csv')
erbs
# Out:
#    grupo    btsId btsNetNome      lat        lon  cch  azimuth    RssiId  \
# 0      1  BTS_1_1  PEMDL01_1 -8.04342 -34.952000  873        0  rssi_1_1
# 1      1  BTS_1_2  PEMDL01_2 -8.04342 -34.952000  872      120  rssi_1_2
# 2      1  BTS_1_3  PEMDL01_3 -8.04342 -34.952000  875      240  rssi_1_3
# 3      2  BTS_2_1  PEMDL08_1 -8.05289 -34.944672  865        0  rssi_2_1
# 4      2  BTS_2_2  PEMDL08_2 -8.05289 -34.944672  874      120  rssi_2_2
# 5      2  BTS_2_3  PEMDL08_3 -8.05289 -34.944672  871      240  rssi_2_3
# 6      3  BTS_3_1  PEMDL09_1 -8.05532 -34.957900  877        0  rssi_3_1
# 7      3  BTS_3_2  PEMDL09_2 -8.05532 -34.957900  881      120  rssi_3_2
# 8      3  BTS_3_3  PEMDL09_3 -8.05532 -34.957900  869      240  rssi_3_3
#
#     Eirp
# 0  55.59
# 1  55.59
# 2  55.59
# 3  55.59
# 4  55.59
# 5  55.59
# 6  55.59
# 7  55.59
# 8  55.59

# %%
db = pd.read_csv('databasesTCC/Outdoordf.csv')
#db = pd.read_csv('databases/meds_pandas.csv')
#db.head()

# %% [markdown]
# # Mostra o mapa com os dados outdoor e localização das erbs

# %%
fig, ax = plt.subplots()
ax.scatter(db['lon'], db['lat'], s = 14, color = 'blue', alpha = 1)
ax.scatter(erbs['lon'], erbs['lat'], s = 50, color = 'red', alpha = 1)
ax.set(xlabel = 'lon', ylabel = 'lat')
plt.axis([-34.961,-34.944,-8.060,-8.043])
plt.gcf().set_size_inches((12,12))
plt.show()

# %%
import numpy as np
test = np.arange(0.25,1.05,0.05)
test
# Out:
# array([0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55, 0.6 , 0.65, 0.7 , 0.75,
#        0.8 , 0.85, 0.9 , 0.95, 1.  ])
